# %%
#access and store github files directly thru code
git_username = 'Jinjhu'
git_reponame = 'AlGo'
git_token = ''
! mkdir -p /root/.ssh 
with open("/root/.ssh/id_rsa", mode="w") as fp: 
    fp.write(""" 
-----BEGIN RSA PRIVATE KEY-----

-----END RSA PRIVATE KEY-----""") 
! ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts 
! chmod go-rwx /root/.ssh/id_rsa 
! git clone git@github.com:{git_username}/{git_reponame}.git 
# %cd /content/{git_reponame}

#!python -m ensurepip --upgrade
#!pip install tf-estimator-nightly==2.8.0.dev2021122109
#!pip install -r requirements.txt #-q --progress-bar off

# !pip install smartapi-python 
# !pip install websocket-client 
# !pip install modin -q --progress-bar off
# !pip install ray  #--force-reinstall
#!pip install pprint

#!pip install pandas #--upgrade 
#!pip install numpy #--upgrade 
#!pip install setuptools #--upgrade

#!pip install python-telegram-bot --upgrade
#!pip install jupyterlab --upgrade
#!pip install jupyter_http_over_ws #--upgrade
#!pip install ta-lib #currently Not Working

from AlGo.data import credentials
from google.colab import output
from google.colab import files


# package import statement
from smartapi import SmartConnect #or from smartapi.smartConnect import SmartConnect
#from smartapi import WebSocket
#import smartapi.smartExceptions(for smartExceptions)
import math
import time
import requests
import csv
import threading
import pprint
#from google.colab import drive
#drive.mount('/content/drive')
import pandas as pd  # for accessing the data and converting it in our format
#import modin.pandas as pd
#import ray
#ray.init(ignore_reinit_error=True)
from smartapi import SmartWebSocket
import multiprocessing
import sys


import tensorflow as tf  
from tensorflow.python.client import device_lib  
tf.test.gpu_device_name()  
device_lib.list_local_devices()  

time.sleep(5)
output.clear()
#%load /content/AlGo/data/credentials.py

#!ls /content/drive/MyDrive/Colab\ Notebooks/algo/code/*.py

# codeToRun after finishing all codes
#!git config --global user.email "your_email@example.com"

#!git config --global user.name "your_name"
#!git add .
#!git commit -a 'writing to GitHub'
#!git push -u origin main

# %%
CLIENT_CODE=credentials.USER_NAME
output.clear()
#create object of call
try:
    obj=SmartConnect(api_key=credentials.API_KEY)
    #login api call
    data = obj.generateSession(credentials.USER_NAME,credentials.PWD)
                                #optional
                                #access_token = "your access token",
                                #refresh_token = "your refresh_token")
    print(data)
    refreshToken= data['data']['refreshToken']
    #fetch the feedtoken
    feedToken=obj.getfeedToken()
    print ("This is my feedtoken::",feedToken)
    #fetch User Profile
    userProfile= obj.getProfile(refreshToken)
    print(userProfile)
    orderbook = obj.orderBook()
    print (orderbook)
except Exception as e:
    print("Login Failed: {}".format(e.message))

# Logout from Account via API
#obj.terminateSession("PUSC1002")         




url = 'https://margincalculator.angelbroking.com/OpenAPI_File/files/OpenAPIScripMaster.json'
d = requests.get(url).json()
global token_df
token_df = pd.DataFrame.from_dict(d)
token_df['expiry'] = pd.to_datetime(token_df['expiry'])
token_df = token_df.astype({'strike': float})
#print(token_df)
#token_df.to_csv('token_df.csv')
#files.download('token_df.csv')

FEED_TOKEN=feedToken
################################################

rms = obj.rmsLimit()
print ("RMS limits ::",rms)

################################################

positions = obj.position()
print ("Positions ::",positions)

################################################

holding = obj.holding()
print ("Holdings ::",holding)

#################################################

stock_portfolio = {"BEL-EQ":"383","ASHOKLEY-EQ":"212","KTKBANK-EQ":"8054","SBIN-EQ":"3045","BAJAJ-AUTO-EQ":"16669","EQUITASBNK-EQ":"913"}
for stock, tokens in stock_portfolio.items():
  print(stock, ":", tokens)
for i in range(0,1):
  print(obj.ltpData("NSE", str(stock), str(tokens)))

#################################################

historicParam={
"exchange": "NSE",
"symboltoken": "2328",
"interval": "FIFTEEN_MINUTE",
"fromdate": '2021-07-01 09:41',
"todate": '2021-07-29 10:41'
}
df = obj.getCandleData(historicParam)
print (df)

################# END ##################################
# Out:
# {'status': True, 'message': 'SUCCESS', 'errorcode': '', 'data': {'clientcode': 'S1366498', 'name': 'SIRANJEEVI M S', 'email': '', 'mobileno': '', 'exchanges': ['bse_cm', 'nse_cm'], 'products': ['BO', 'NRML', 'CO', 'CNC', 'MIS', 'MARGIN'], 'lastlogintime': '', 'broker': '', 'jwtToken': 'Bearer eyJhbGciOiJIUzUxMiJ9.eyJ1c2VybmFtZSI6IlMxMzY2NDk4Iiwicm9sZXMiOjAsInVzZXJ0eXBlIjoiVVNFUiIsImlhdCI6MTY1MTIxMzUxMiwiZXhwIjoxNzM3NjEzNTEyfQ.pL_1IUbawGDOHPW2iBS5m2Mp-ThR_S_9a0bB25Hdk7ppPEtPqJs_l-yHXLnj3WZN4Qi48JSmyuhCtpKTBzs7bQ', 'refreshToken': 'eyJhbGciOiJIUzUxMiJ9.eyJ0b2tlbiI6IlJFRlJFU0gtVE9LRU4iLCJpYXQiOjE2NTEyMTM1MTJ9.oGi4VRXjna-bb32ubnQtFNFmZ6to_ZT8LYFWvwQy0TRNvWYQm8zX6BqtlyuNlXA6orpt8EbPsnDQhACcDCZ8FQ'}}
# This is my feedtoken:: 0954276480
# ...

# %%
print(orderbook)
# Out:
# {'status': True, 'message': 'SUCCESS', 'errorcode': '', 'data': [{'variety': 'NORMAL', 'ordertype': 'LIMIT', 'producttype': 'INTRADAY', 'duration': 'DAY', 'price': 1422.45, 'triggerprice': 1422.5, 'quantity': '24', 'disclosedquantity': '0', 'squareoff': 0.0, 'stoploss': 0.0, 'trailingstoploss': 0.0, 'tradingsymbol': 'AUBANK-EQ', 'transactiontype': 'SELL', 'exchange': 'NSE', 'symboltoken': '21238', 'ordertag': '', 'instrumenttype': '', 'strikeprice': -1.0, 'optiontype': '', 'expirydate': '', 'lotsize': '1', 'cancelsize': '0', 'averageprice': 1422.45, 'filledshares': '24', 'unfilledshares': '0', 'orderid': '220429000025907', 'text': '', 'status': 'complete', 'orderstatus': 'complete', 'updatetime': '29-Apr-2022 09:28:33', 'exchtime': '29-Apr-2022 09:15:12', 'exchorderupdatetime': '29-Apr-2022 09:28:33', 'fillid': '', 'filltime': '', 'parentorderid': ''}, {'variety': 'NORMAL', 'ordertype': 'LIMIT', 'producttype': 'INTRADAY', 'duration': 'DAY', 'price': 249.45, 'triggerprice': 249.5, 'qu
# ...

# %%
tradebook=obj.tradeBook()
print(tradebook)
# Out:
# {'status': True, 'message': 'SUCCESS', 'errorcode': '', 'data': [{'exchange': 'NSE', 'producttype': 'INTRADAY', 'tradingsymbol': 'AUBANK-EQ', 'instrumenttype': '', 'symbolgroup': 'EQ', 'strikeprice': -1.0, 'optiontype': '', 'expirydate': '', 'marketlot': '1', 'precision': '2', 'multiplier': '-1', 'tradevalue': 1422.45, 'transactiontype': 'SELL', 'fillprice': 1422.45, 'fillsize': '1', 'orderid': '220429000025907', 'fillid': '710314', 'filltime': '09:28:32'}, {'exchange': 'NSE', 'producttype': 'INTRADAY', 'tradingsymbol': 'AUBANK-EQ', 'instrumenttype': '', 'symbolgroup': 'EQ', 'strikeprice': -1.0, 'optiontype': '', 'expirydate': '', 'marketlot': '1', 'precision': '2', 'multiplier': '-1', 'tradevalue': 12802.05, 'transactiontype': 'SELL', 'fillprice': 1422.45, 'fillsize': '9', 'orderid': '220429000025907', 'fillid': '710313', 'filltime': '09:28:32'}, {'exchange': 'NSE', 'producttype': 'INTRADAY', 'tradingsymbol': 'PERSISTENT-EQ', 'instrumenttype': '', 'symbolgroup': 'EQ', 'strikeprice':
# ...

# %%
print(positions)
print(positions.get('data'))
if positions['data'] !=None:
  print(type(positions['data']))
  print(type(positions['data'][0]))
  print(positions['data'][0].keys())
# Out:
# {'status': True, 'message': 'SUCCESS', 'errorcode': '', 'data': [{'symboltoken': '1512', 'symbolname': 'INDHOTEL', 'instrumenttype': '', 'priceden': '1.00', 'pricenum': '1.00', 'genden': '1.00', 'gennum': '1.00', 'precision': '2', 'multiplier': '-1', 'boardlotsize': '1', 'exchange': 'NSE', 'producttype': 'INTRADAY', 'tradingsymbol': 'INDHOTEL-EQ', 'symbolgroup': 'EQ', 'strikeprice': '-1', 'optiontype': '', 'expirydate': '', 'lotsize': '1', 'cfbuyqty': '0', 'cfsellqty': '0', 'cfbuyamount': '0.00', 'cfsellamount': '0.00', 'buyavgprice': '0.00', 'sellavgprice': '249.45', 'avgnetprice': '249.45', 'netvalue': '34923.00', 'netqty': '-140', 'totalbuyvalue': '0.00', 'totalsellvalue': '34923.00', 'cfbuyavgprice': '0.00', 'cfsellavgprice': '0.00', 'totalbuyavgprice': '0.00', 'totalsellavgprice': '249.45', 'netprice': '249.45', 'buyqty': '0', 'sellqty': '140', 'buyamount': '0.00', 'sellamount': '34923.00', 'pnl': '-749.00', 'realised': '0.00', 'unrealised': '-749.00', 'ltp': '254.8', 'close': '
# ...

# %%
orderbook
# Out:
# {'data': [{'averageprice': 1422.45,
#    'cancelsize': '0',
#    'disclosedquantity': '0',
#    'duration': 'DAY',
#    'exchange': 'NSE',
#    'exchorderupdatetime': '29-Apr-2022 09:28:33',
#    'exchtime': '29-Apr-2022 09:15:12',
#    'expirydate': '',
#    'filledshares': '24',
#    'fillid': '',
#    'filltime': '',
#    'instrumenttype': '',
#    'lotsize': '1',
#    'optiontype': '',
#    'orderid': '220429000025907',
#    'orderstatus': 'complete',
#    'ordertag': '',
#    'ordertype': 'LIMIT',
#    'parentorderid': '',
#    'price': 1422.45,
#    'producttype': 'INTRADAY',
#    'quantity': '24',
#    'squareoff': 0.0,
#    'status': 'complete',
#    'stoploss': 0.0,
#    'strikeprice': -1.0,
#    'symboltoken': '21238',
#    'text': '',
#    'tradingsymbol': 'AUBANK-EQ',
#    'trailingstoploss': 0.0,
#    'transactiontype': 'SELL',
#    'triggerprice': 1422.5,
#    'unfilledshares': '0',
#    'updatetime': '29-Apr-2022 09:28:33',
#    'variety': 'NORMAL'},
# ...

# %%
import math
reps=1
while reps<=99:
  output.clear()
  positions = obj.position()
  net_pnl=[]
  if positions['data'] !=None:
    for i in range(len(positions['data'])):
      print(positions['data'][i]['symbolname'],":",positions['data'][i]['pnl'])
      #print(positions['data'][i]['realised'])
      #print(positions['data'][i]['unrealised'])
      net_pnl.append(float(positions['data'][i]['pnl']))
      #print(math.fsum(net_pnl))
      #print(type(net_pnl))
      
      #if i!=0: net_pnl+=net_pnl
  elif positions['data'] ==None:
    break
  
  print(math.fsum(net_pnl))
  time.sleep(9)  
  
  reps+=1
# Out:
# INDHOTEL : -735.00
# UPL : 132.30
# AUBANK : 363.60
# UBL : -418.00
# PERSISTENT : 46.00
# COROMANDEL : -9.50
# -620.5999999999999

# %%
token_df[['symbol']]
for index in range(token_df.shape[1]):
  columnSeriesObj = token_df.iloc[:, index]
print(columnSeriesObj)
  #print(obj.ltpData("NSE", str(token_df[['symbol']]), str(token_df[['token']])))
# Out:
# 0           1.000000
# 1           1.000000
# 2           5.000000
# 3           1.000000
# 4           1.000000
#              ...
# 104496      1.000000
# 104497    100.000000
# 104498    100.000000
# 104499     50.000000
# 104500     50.000000
# Name: tick_size, Length: 104501, dtype: object

# %%
#code to keep the google collab running without disconnecting

#Well I am not a python guy nor I know what is the actual use of this 'Colab',
#   I use it as a build system lol. And I used to setup ssh forwarding in it 
#     then put this code and just leave it running and yeah it works.

import getpass
authtoken = getpass.getpass()

EXCHANGE = "nse_cm"
TOKEN_SYMBOL = ['2885','1594','11536','3045']
for TOKEN in TOKEN_SYMBOL:
  token_list=token_list+EXCHANGE+"|"+TOKEN+"&"    #"EXCHANGE|TOKEN_SYMBOL" #SAMPLE: nse_cm|2885&nse_cm|1594&nse_cm|11536&nse_cm|3045

task="mw" # mw|sfi|dp

ss = SmartWebSocket(FEED_TOKEN, CLIENT_CODE)

def on_message(ws, message):
  #output.clear()
  print("Ticks: {}".format(message))

def on_open(ws):
  print("on open")
  ss.subscribe(task,token_list)

def on_error(ws, error):
  print(error)

def on_close(ws):
  print("Close")

ss._on_open = on_open
ss._on_message = on_message
ss._on_error = on_error
ss._on_close = on_close

ss.connect()
p1 = multiprocessing.Process(target = ss.connect())
sys.exit()
p1.start()
# Out:
# Streaming output truncated to the last 5000 lines.
# Ticks: [{'ap': '3601.64', 'bp': '3605.10', 'bq': '49', 'bs': '204', 'c': '3584.30', 'cng': '20.80', 'e': 'nse_cm', 'lo': '3584.20', 'ltp': '3605.10', 'ltq': '2', 'ltt': '29/04/2022 13:54:17', 'name': 'sf', 'nc': '00.5803', 'sp': '3605.45', 'tbq': '127578', 'tk': '11536', 'to': '3291347909.08', 'tsq': '208147', 'v': '913847'}, {'ap': '2837.34', 'bp': '2838.30', 'bq': '49', 'bs': '18', 'c': '2819.85', 'cng': '18.45', 'e': 'nse_cm', 'lo': '2821.35', 'ltp': '2838.30', 'ltq': '6', 'ltt': '29/04/2022 13:54:17', 'name': 'sf', 'nc': '00.6543', 'sp': '2838.55', 'tbq': '226654', 'tk': '2885', 'to': '11017238003.64', 'tsq': '595520', 'v': '3882946'}, {'e': 'nse_cm', 'ltp': '3605.45', 'ltq': '1', 'ltt': 'NA', 'name': 'sf', 'tk': '11536'}]
# Ticks: [{'name': 'tm', 'tvalue': '29/04/2022 13:54:18'}]
# ...

# %%
print(type(obj))
obj.getfeedToken()
